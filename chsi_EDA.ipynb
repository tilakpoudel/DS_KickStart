# %%
import pandas as pd
import numpy as np 
# to see all the columns while viewing data 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('data_set/chsi/RELATIVEHEALTHIMPORTANCE.csv')

# %%
data.head(20)
# Out:
#     State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                 1                 1          Autauga         Alabama
# 1                 1                 3          Baldwin         Alabama
# 2                 1                 5          Barbour         Alabama
# 3                 1                 7             Bibb         Alabama
# 4                 1                 9           Blount         Alabama
# 5                 1                11          Bullock         Alabama
# 6                 1                13           Butler         Alabama
# 7                 1                15          Calhoun         Alabama
# 8                 1                17         Chambers         Alabama
# 9                 1                19         Cherokee         Alabama
# 10                1                21          Chilton         Alabama
# 11                1                23          Choctaw         Alabama
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   State_FIPS_Code           3141 non-null   int64
#  1   County_FIPS_Code          3141 non-null   int64
#  2   CHSI_County_Name          3141 non-null   object
#  3   CHSI_State_Name           3141 non-null   object
#  4   CHSI_State_Abbr           3141 non-null   object
#  5   Strata_ID_Number          3141 non-null   int64
#  6   RHI_LBW_Ind               3141 non-null   int64
#  7   RHI_VLBW_Ind              3141 non-null   int64
#  8   RHI_Premature_Ind         3141 non-null   int64
#  9   RHI_Under_18_Ind          3141 non-null   int64
#  10  RHI_Over_40_Ind           3141 non-null   int64
#  11  RHI_Unmarried_Ind         3141 non-null   int64
#  12  RHI_Late_Care_Ind         3141 non-null   int64
#  13  RHI_Infant_Mortality_Ind  3141 non-null   int64
# ...

# %%
data.shape
# Out:
# (3141, 28)

# %%
data.columns
# Out:
# Index(['State_FIPS_Code', 'County_FIPS_Code', 'CHSI_County_Name',
#        'CHSI_State_Name', 'CHSI_State_Abbr', 'Strata_ID_Number', 'RHI_LBW_Ind',
#        'RHI_VLBW_Ind', 'RHI_Premature_Ind', 'RHI_Under_18_Ind',
#        'RHI_Over_40_Ind', 'RHI_Unmarried_Ind', 'RHI_Late_Care_Ind',
#        'RHI_Infant_Mortality_Ind', 'RHI_IM_Wh_Non_Hisp_Ind',
#        'RHI_IM_Bl_Non_Hisp_Ind', 'RHI_IM_Hisp_Ind', 'RHI_IM_Neonatal_Ind',
#        'RHI_IM_Postneonatal_Ind', 'RHI_Brst_Cancer_Ind', 'RHI_Col_Cancer_Ind',
#        'RHI_CHD_Ind', 'RHI_Homicide_Ind', 'RHI_Lung_Cancer_Ind', 'RHI_MVA_Ind',
#        'RHI_Stroke_Ind', 'RHI_Suicide_Ind', 'RHI_Injury_Ind'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# State_FIPS_Code             0
# County_FIPS_Code            0
# CHSI_County_Name            0
# CHSI_State_Name             0
# CHSI_State_Abbr             0
# Strata_ID_Number            0
# RHI_LBW_Ind                 0
# RHI_VLBW_Ind                0
# RHI_Premature_Ind           0
# RHI_Under_18_Ind            0
# RHI_Over_40_Ind             0
# RHI_Unmarried_Ind           0
# RHI_Late_Care_Ind           0
# RHI_Infant_Mortality_Ind    0
# RHI_IM_Wh_Non_Hisp_Ind      0
# RHI_IM_Bl_Non_Hisp_Ind      0
# RHI_IM_Hisp_Ind             0
# RHI_IM_Neonatal_Ind         0
# RHI_IM_Postneonatal_Ind     0
# RHI_Brst_Cancer_Ind         0
# RHI_Col_Cancer_Ind          0
# RHI_CHD_Ind                 0
# RHI_Homicide_Ind            0
# RHI_Lung_Cancer_Ind         0
# RHI_MVA_Ind                 0
# RHI_Stroke_Ind              0
# RHI_Suicide_Ind             0
# RHI_Injury_Ind              0
# dtype: int64

# %%
# display all the columns in for large number of columns
data.columns.values
# Out:
# array(['State_FIPS_Code', 'County_FIPS_Code', 'CHSI_County_Name',
#        'CHSI_State_Name', 'CHSI_State_Abbr', 'Strata_ID_Number',
#        'RHI_LBW_Ind', 'RHI_VLBW_Ind', 'RHI_Premature_Ind',
#        'RHI_Under_18_Ind', 'RHI_Over_40_Ind', 'RHI_Unmarried_Ind',
#        'RHI_Late_Care_Ind', 'RHI_Infant_Mortality_Ind',
#        'RHI_IM_Wh_Non_Hisp_Ind', 'RHI_IM_Bl_Non_Hisp_Ind',
#        'RHI_IM_Hisp_Ind', 'RHI_IM_Neonatal_Ind',
#        'RHI_IM_Postneonatal_Ind', 'RHI_Brst_Cancer_Ind',
#        'RHI_Col_Cancer_Ind', 'RHI_CHD_Ind', 'RHI_Homicide_Ind',
#        'RHI_Lung_Cancer_Ind', 'RHI_MVA_Ind', 'RHI_Stroke_Ind',
#        'RHI_Suicide_Ind', 'RHI_Injury_Ind'], dtype=object)

# %%
data.describe(include='object')
# Out:
#        CHSI_County_Name CHSI_State_Name CHSI_State_Abbr
# count              3141            3141            3141
# unique             1847              51              51
# top          Washington           Texas              TX
# freq                 32             254             254

# %%
# get the unique values count(remove shape to view the unique values) in the mentioned column
data['CHSI_State_Name'].unique().shape
# Out:
# (51,)

# %%
(data['CHSI_County_Name']== 'Washington').sum()
# Out:
# 32

# %%
help(data.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False) method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#             by : str or list of str
#                 Name or list of names to sort by.
#
#                 - if `axis` is 0 or `'index'` then `by` may contain index
#                   levels and/or column labels.
#                 - if `axis` is 1 or `'columns'` then `by` may contain column
#                   levels and/or index labels.
#
#                 .. versionchanged:: 0.23.0
#
#                    Allow specifying index or column level names.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
# ...

# %%
sort_by_cancer=data.sort_values(by=['RHI_Premature_Ind','RHI_Brst_Cancer_Ind'],ascending=[False,False])
sort_by_cancer[['CHSI_County_Name','CHSI_State_Name','RHI_Premature_Ind','RHI_Brst_Cancer_Ind']].head(10)
# Out:
#    CHSI_County_Name CHSI_State_Name  RHI_Premature_Ind  RHI_Brst_Cancer_Ind
# 0           Autauga         Alabama                  8                    8
# 2           Barbour         Alabama                  8                    8
# 3              Bibb         Alabama                  8                    8
# 4            Blount         Alabama                  8                    8
# 5           Bullock         Alabama                  8                    8
# 7           Calhoun         Alabama                  8                    8
# 8          Chambers         Alabama                  8                    8
# 16          Colbert         Alabama                  8                    8
# 19        Covington         Alabama                  8                    8
# 21          Cullman         Alabama                  8                    8

# %%
data[data['CHSI_State_Name']== 'Alabama'].mean()
# Out:
# State_FIPS_Code              1.00
# County_FIPS_Code            67.00
# Strata_ID_Number            40.97
# RHI_LBW_Ind                  7.73
# RHI_VLBW_Ind                 7.60
# RHI_Premature_Ind            7.72
# RHI_Under_18_Ind             7.42
# RHI_Over_40_Ind              5.51
# RHI_Unmarried_Ind            6.18
# RHI_Late_Care_Ind            6.63
# RHI_Infant_Mortality_Ind     7.30
# RHI_IM_Wh_Non_Hisp_Ind       5.99
# RHI_IM_Bl_Non_Hisp_Ind       5.06
# RHI_IM_Hisp_Ind             -0.33
# RHI_IM_Neonatal_Ind          7.04
# RHI_IM_Postneonatal_Ind      7.19
# RHI_Brst_Cancer_Ind          6.61
# RHI_Col_Cancer_Ind           5.81
# RHI_CHD_Ind                  5.85
# RHI_Homicide_Ind             6.63
# RHI_Lung_Cancer_Ind          6.85
# RHI_MVA_Ind                  7.61
# RHI_Stroke_Ind               7.18
# RHI_Suicide_Ind              5.99
# RHI_Injury_Ind               6.27
# dtype: float64

# %%
data.corr(method ='pearson')
# Out:
#                           State_FIPS_Code  County_FIPS_Code  Strata_ID_Number  \
# State_FIPS_Code                  1.00e+00          1.66e-01          1.87e-04
# County_FIPS_Code                 1.66e-01          1.00e+00          4.43e-02
# Strata_ID_Number                 1.87e-04          4.43e-02          1.00e+00
# RHI_LBW_Ind                     -6.42e-02          3.75e-02         -6.15e-02
# RHI_VLBW_Ind                    -7.98e-02          1.71e-02         -2.99e-01
# RHI_Premature_Ind               -6.89e-03          8.31e-02         -3.34e-02
# RHI_Under_18_Ind                -5.20e-02          1.38e-01         -8.97e-02
# RHI_Over_40_Ind                 -3.23e-02         -7.12e-02         -2.36e-01
# RHI_Unmarried_Ind               -6.65e-02          4.15e-02         -4.35e-02
# RHI_Late_Care_Ind               -1.44e-01          6.52e-02          1.51e-01
# RHI_Infant_Mortality_Ind        -6.20e-02         -2.61e-03         -3.15e-01
# ...

# %%
data['RHI_Premature_Ind'].corr(data['RHI_Brst_Cancer_Ind'])
# Out:
# 0.13010704520442362

# %%
columns_to_show = ['CHSI_State_Name', 'RHI_Premature_Ind', 
                   'RHI_Brst_Cancer_Ind']

data.groupby(['CHSI_State_Name'])[columns_to_show].describe(percentiles=[])
# Out:
#                      RHI_Premature_Ind                             \
#                                  count  mean   std  min  50%  max
# CHSI_State_Name
# Alabama                           67.0  7.72  0.81  5.0  8.0  8.0
# Alaska                            27.0  5.26  2.18 -1.0  5.0  8.0
# Arizona                           15.0  6.27  1.39  5.0  6.0  8.0
# Arkansas                          75.0  6.61  1.36  5.0  7.0  8.0
# California                        58.0  5.10  0.45  5.0  5.0  7.0
# Colorado                          64.0  6.27  1.59 -2.0  7.0  8.0
# Connecticut                        8.0  5.00  0.00  5.0  5.0  5.0
# Delaware                           3.0  7.33  1.15  6.0  8.0  8.0
# District of Columbia               1.0  8.00   NaN  8.0  8.0  8.0
# Florida                           67.0  6.63  1.29  5.0  6.0  8.0
# Georgia                          159.0  6.55  1.31  5.0  6.0  8.0
# Hawaii                             5.0  5.40  3.78 -1.0  7.0  8.0
# ...

# %%
# crosstab helps to compare between two columns easily
pd.crosstab(data['CHSI_State_Name'], data['RHI_Premature_Ind'])
# Out:
# RHI_Premature_Ind     -2  -1   5   6   7    8
# CHSI_State_Name
# Alabama                0   0   4   3   1   59
# Alaska                 0   2  18   0   2    5
# Arizona                0   0   7   2   1    5
# Arkansas               0   0  26  11   4   34
# California             0   0  55   0   3    0
# Colorado               1   0  23   6  20   14
# Connecticut            0   0   8   0   0    0
# Delaware               0   0   0   1   0    2
# District of Columbia   0   0   0   0   0    1
# Florida                0   0  19  15   5   28
# Georgia                0   0  53  29  14   63
# Hawaii                 0   1   1   0   1    2
# Idaho                  0   0  39   0   4    1
# Illinois               0   0  35   2  32   33
# Indiana                0   0  25   0  33   34
# Iowa                   0   0  51   0  39    9
# Kansas                 0   0  48   1  39   17
# Kentucky               0   0  43  22   7   48
# Louisiana              0   0   7  10   0   47
# ...

# %%
# pivot table can be used to summarize the data using agg function
data.pivot_table(['RHI_Premature_Ind','RHI_Brst_Cancer_Ind'],
               ['CHSI_State_Name'], aggfunc='mean')
# Out:
#                       RHI_Brst_Cancer_Ind  RHI_Premature_Ind
# CHSI_State_Name
# Alabama                              6.61               7.72
# Alaska                               0.89               5.26
# Arizona                              5.73               6.27
# Arkansas                             6.19               6.61
# California                           5.40               5.10
# Colorado                             3.12               6.27
# Connecticut                          6.50               5.00
# Delaware                             6.33               7.33
# District of Columbia                 8.00               8.00
# Florida                              5.69               6.63
# Georgia                              5.60               6.55
# Hawaii                               3.80               5.40
# Idaho                                4.75               5.25
# Illinois                             6.24               6.62
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x='CHSI_State_Name', hue='RHI_Premature_Ind', data=data);

# %%
# Quick inspection of the data
# data.plot.barh(x='CHSI_State_Name', 
#                 y= 'RHI_Premature_Ind',
#                 figsize = (15, 10),
#                )
